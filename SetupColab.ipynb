# %% [markdown]
# <a href="https://colab.research.google.com/github/jainashwin/lca-langchainV1-essentials/blob/Day1-Development/SetupColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
from getpass import getpass

# 1. Mount Google Drive
drive.mount('/content/drive')

# Define the path where your GitHub repo will be stored on Drive
# This ensures persistent storage across Colab sessions
repo_path = '/content/drive/MyDrive/GitHub/lca-langchainV1-essentials'

# Create the directory if it doesn't exist
os.makedirs(repo_path, exist_ok=True)
# %cd {repo_path}

# 2. Store your GitHub Personal Access Token securely
# You will be prompted to enter your PAT here.
GIT_PAT = getpass('Enter your GitHub Personal Access Token (PAT): ')

# 3. Configure Git user information (optional, but good practice)
# !git config --global user.email "ashwinjain77@gmail.com" # Replace with your email
# !git config --global user.name "Ashwin" # Replace with your name

print(f"Directory changed to: {os.getcwd()}")
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/GitHub/lca-langchainV1-essentials
# Enter your GitHub Personal Access Token (PAT): ··········
# Directory changed to: /content/drive/MyDrive/GitHub/lca-langchainV1-essentials

# %%
# The URL for your forked repo, using the PAT for authentication
repo_url = f"https://{GIT_PAT}@github.com/jainashwin/lca-langchainV1-essentials.git"

# Clone the repository (if not already cloned)
if not os.path.exists('.git'):
    print("Cloning repository...")
    # !git clone {repo_url} .
    print("Cloning complete.")
else:
    print("Repository already exists. Pulling latest changes...")
    # !git pull
# Out:
# Cloning repository...
# Cloning into '.'...
# remote: Enumerating objects: 534, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 534 (delta 140), reused 122 (delta 113), pack-reused 367 (from 1)
# Receiving objects: 100% (534/534), 3.33 MiB | 11.84 MiB/s, done.
# Resolving deltas: 100% (356/356), done.
# Cloning complete.

# %%
branch_name = 'Day1-Development'

# Checkout your specific branch
# !git checkout {branch_name}
print(f"Switched to branch: {branch_name}")

# Pull the latest changes for that branch to be sure you are up to date
# !git pull origin {branch_name}
# Out:
# Branch 'Day1-Development' set up to track remote branch 'Day1-Development' from 'origin'.
# Switched to a new branch 'Day1-Development'
# Switched to branch: Day1-Development
# From https://github.com/jainashwin/lca-langchainV1-essentials
#  * branch            Day1-Development -> FETCH_HEAD
# Already up to date.

# %%
# Ensure you are in the repository root directory in case you opened a notebook elsewhere
# %cd /content/drive/MyDrive/GitHub/lca-langchainV1-essentials

# Check the status of modified files
# !git status

# Stage all changes
# !git add .

# Commit changes
commit_message = "Your descriptive commit message here"
# !git commit -m "{commit_message}"

# Push changes to your specific branch on GitHub
# !git push origin {branch_name}
